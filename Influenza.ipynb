# %%
# !wget https://api.ukhsa-dashboard.data.gov.uk/themes/infectious_disease/sub_themes/respiratory/topics/Influenza/geography_types/Nation/geographies/England/metrics/influenza_healthcare_hospitalAdmissionRateByWeek
# Out:
# --2024-10-24 15:46:46--  https://api.ukhsa-dashboard.data.gov.uk/themes/infectious_disease/sub_themes/respiratory/topics/Influenza/geography_types/Nation/geographies/England/metrics/influenza_healthcare_hospitalAdmissionRateByWeek
# Resolving api.ukhsa-dashboard.data.gov.uk (api.ukhsa-dashboard.data.gov.uk)... 108.138.217.42, 108.138.217.58, 108.138.217.88, ...
# Connecting to api.ukhsa-dashboard.data.gov.uk (api.ukhsa-dashboard.data.gov.uk)|108.138.217.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2234 (2.2K) [application/json]
# Saving to: ‘influenza_healthcare_hospitalAdmissionRateByWeek’
#
# influenza_healthcar 100%[===================>]   2.18K  --.-KB/s    in 0s
#
# 2024-10-24 15:46:46 (861 MB/s) - ‘influenza_healthcare_hospitalAdmissionRateByWeek’ saved [2234/2234]

# %%
# !cat influenza_healthcare_hospitalAdmissionRateByWeek
# Out:
# {"count":2238,"next":"https://api.ukhsa-dashboard.data.gov.uk/themes/infectious_disease/sub_themes/respiratory/topics/Influenza/geography_types/Nation/geographies/England/metrics/influenza_healthcare_hospitalAdmissionRateByWeek?page=2","previous":null,"results":[{"theme":"infectious_disease","sub_theme":"respiratory","topic":"Influenza","geography_type":"Nation","geography":"England","geography_code":"E92000001","metric":"influenza_healthcare_hospitalAdmissionRateByWeek","metric_group":"healthcare","stratum":"default","sex":"all","age":"all","year":2015,"month":6,"epiweek":27,"date":"2015-06-29","metric_value":0.0,"in_reporting_delay_period":false},{"theme":"infectious_disease","sub_theme":"respiratory","topic":"Influenza","geography_type":"Nation","geography":"England","geography_code":"E92000001","metric":"influenza_healthcare_hospitalAdmissionRateByWeek","metric_group":"healthcare","stratum":"default","sex":"all","age":"all","year":2015,"month":7,"epiweek":28,"date":"2015-07-06","metric_value":0.0,"in_reporting_delay_period":false},{"theme":"infectious_disease","sub_theme":"respiratory","topic":"Influenza","geography_type":"Nation","geography":"England","geography_code":"E92000001","metric":"influenza_healthcare_hospitalAdmissionRateByWeek","metric_group":"healthcare","stratum":"default","sex":"all","age":"all","year":2015,"month":7,"epiweek":29,"date":"2015-07-13","metric_value":0.0,"in_reporting_delay_period":false},{"theme":"infectious_disease","sub_theme":"respiratory","topic":"Influenza","geography_type":"Nation","geography":"England","geography_code":"E92000001","metric":"influenza_healthcare_hospitalAdmissionRateByWeek","metric_group":"healthcare","stratum":"default","sex":"all","age":"all","year":2015,"month":7,"epiweek":30,"date":"2015-07-20","metric_value":0.0,"in_reporting_delay_period":false},{"theme":"infectious_disease","sub_theme":"respiratory","topic":"Influenza","geography_type":"Nation","geography":"England","geography_code":"E92000001","metric":"influenza_healthcare_hospitalAdmissionRateByWeek","metric_group":"healthcare","stratum":"default","sex":"all","age":"all","year":2015,"month":7,"epiweek":31,"date":"2015-07-27","metric_value":0.0,"in_reporting_delay_period":false}]}

# %%
import requests

# Same as the above but in Python, with a couple of extra parameters added to the URL
requests.get("https://api.ukhsa-dashboard.data.gov.uk/themes"
             "/infectious_disease/sub_themes/respiratory/topics"
             "/Influenza/geography_types/Nation/geographies/England"
             "/metrics/influenza_healthcare_hospitalAdmissionRateByWeek", 
             params={'year': 2015, 'page_size': 3, 'page': 2}).json()
# Out:
# {'count': 26,
#  'next': 'https://api.ukhsa-dashboard.data.gov.uk/themes/infectious_disease/sub_themes/respiratory/topics/Influenza/geography_types/Nation/geographies/England/metrics/influenza_healthcare_hospitalAdmissionRateByWeek?page=3&page_size=3&year=2015',
#  'previous': 'https://api.ukhsa-dashboard.data.gov.uk/themes/infectious_disease/sub_themes/respiratory/topics/Influenza/geography_types/Nation/geographies/England/metrics/influenza_healthcare_hospitalAdmissionRateByWeek?page_size=3&year=2015',
#  'results': [{'theme': 'infectious_disease',
#    'sub_theme': 'respiratory',
#    'topic': 'Influenza',
#    'geography_type': 'Nation',
#    'geography': 'England',
#    'geography_code': 'E92000001',
#    'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#    'metric_group': 'healthcare',
#    'stratum': 'default',
#    'sex': 'all',
#    'age': 'all',
#    'year': 2015,
#    'month': 7,
#    'epiweek': 30,
#    'date': '2015-07-20',
#    'metric_value': 0.0,
#    'in_reporting_delay_period': False},
#   {'theme': 'infectious_disease',
#    'sub_theme': 'respiratory',
#    'topic': 'Influenza',
#    'geography_type': 'Nation',
#    'geography': 'England',
#    'geography_code': 'E92000001',
#    'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#    'metric_group': 'healthcare',
#    'stratum': 'default',
#    'sex': 'all',
#    'age': 'all',
#    'year': 2015,
#    'month': 7,
#    'epiweek': 31,
#    'date': '2015-07-27',
#    'metric_value': 0.0,
#    'in_reporting_delay_period': False},
#   {'theme': 'infectious_disease',
#    'sub_theme': 'respiratory',
#    'topic': 'Influenza',
#    'geography_type': 'Nation',
#    'geography': 'England',
#    'geography_code': 'E92000001',
#    'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#    'metric_group': 'healthcare',
#    'stratum': 'default',
#    'sex': 'all',
#    'age': 'all',
#    'year': 2015,
#    'month': 8,
#    'epiweek': 32,
#    'date': '2015-08-03',
#    'metric_value': 0.0,
#    'in_reporting_delay_period': False}]}

# %%
import requests
import time

class APIwrapper:
    # class variables shared among all instances
    _access_point="https://api.ukhsa-dashboard.data.gov.uk"
    _last_access=0.0 # time of last api access
    
    def __init__(self, theme, sub_theme, topic, geography_type, geography, metric):
        """ Init the APIwrapper object, constructing the endpoint from the structure
        parameters """
        # build the path with all the required structure parameters
        url_path=(f"/themes/{theme}/sub_themes/{sub_theme}/topics/{topic}/geography_types/" +
                  f"{geography_type}/geographies/{geography}/metrics/{metric}")
        # our starting API endpoint
        self._start_url=APIwrapper._access_point+url_path
        self._filters=None
        self._page_size=-1
        # will contain the number of items
        self.count=None

    def get_page(self, filters={}, page_size=5):
        """ Access the API and download the next page of data. Sets the count
        attribute to the total number of items available for this query. Changing
        filters or page_size will cause get_page to restart from page 1. Rate
        limited to three request per second. The page_size parameter sets the number
        of data points in one response page (maximum 42); use the default value 
        for debugging your structure and filters, increase when you start looping 
        over all pages. """
    # Check page size is within range
        if page_size>26:
            raise ValueError("Max supported page size is 42")
        # restart from first page if page or filters have changed
        if filters!=self._filters or page_size!=self._page_size:
            self._filters=filters
            self._page_size=page_size
            self._next_url=self._start_url
        # signal the end of data condition
        if self._next_url==None: 
            return [] # we already fetched the last page
        # simple rate limiting to avoid bans
        curr_time=time.time() # Unix time: number of seconds since the Epoch
        deltat=curr_time-APIwrapper._last_access
        if deltat<0.33: # max 3 requests/second
            time.sleep(0.33-deltat)
        APIwrapper._last_access=curr_time
        # build parameter dictionary by removing all the None
        # values from filters and adding page_size
        parameters={x: y for x, y in filters.items() if y!=None}
        parameters['page_size']=page_size
        # the page parameter is already included in _next_url.
        # This is the API access. Response is a dictionary with various keys.
        # the .json() method decodes the response into Python object (dictionaries,
        # lists; 'null' values are translated as None).
        response = requests.get(self._next_url, params=parameters).json()
        # update url so we'll fetch the next page
        self._next_url=response['next']
        self.count=response['count']
        # data are in the nested 'results' list
        return response['results']

# %%
structure={"theme": "infectious_disease", 
           "sub_theme": "respiratory",
           "topic": "Influenza",
           "geography_type": "Nation", 
           "geography": "England"}

# %%
structure["metric"]="influenza_healthcare_hospitalAdmissionRateByWeek"

# %%
# ** unpacks the structure dictionary over the __init__ arguments
api=APIwrapper(**structure)
data=api.get_page() # default size is 5
print(api.count)
print(data)
# Out:
# 2238
# [{'theme': 'infectious_disease', 'sub_theme': 'respiratory', 'topic': 'Influenza', 'geography_type': 'Nation', 'geography': 'England', 'geography_code': 'E92000001', 'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek', 'metric_group': 'healthcare', 'stratum': 'default', 'sex': 'all', 'age': 'all', 'year': 2015, 'month': 6, 'epiweek': 27, 'date': '2015-06-29', 'metric_value': 0.0, 'in_reporting_delay_period': False}, {'theme': 'infectious_disease', 'sub_theme': 'respiratory', 'topic': 'Influenza', 'geography_type': 'Nation', 'geography': 'England', 'geography_code': 'E92000001', 'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek', 'metric_group': 'healthcare', 'stratum': 'default', 'sex': 'all', 'age': 'all', 'year': 2015, 'month': 7, 'epiweek': 28, 'date': '2015-07-06', 'metric_value': 0.0, 'in_reporting_delay_period': False}, {'theme': 'infectious_disease', 'sub_theme': 'respiratory', 'topic': 'Influenza', 'geography_type': 'Nation', 'geography': 'England', 'geography_code': 'E92000001', 'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek', 'metric_group': 'healthcare', 'stratum': 'default', 'sex': 'all', 'age': 'all', 'year': 2015, 'month': 7, 'epiweek': 29, 'date': '2015-07-13', 'metric_value': 0.0, 'in_reporting_delay_period': False}, {'theme': 'infectious_disease', 'sub_theme': 'respiratory', 'topic': 'Influenza', 'geography_type': 'Nation', 'geography': 'England', 'geography_code': 'E92000001', 'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek', 'metric_group': 'healthcare', 'stratum': 'default', 'sex': 'all', 'age': 'all', 'year': 2015, 'month': 7, 'epiweek': 30, 'date': '2015-07-20', 'metric_value': 0.0, 'in_reporting_delay_period': False}, {'theme': 'infectious_disease', 'sub_theme': 'respiratory', 'topic': 'Influenza', 'geography_type': 'Nation', 'geography': 'England', 'geography_code': 'E92000001', 'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek', 'metric_group': 'healthcare', 'stratum': 'default', 'sex': 'all', 'age': 'all', 'year': 2015, 'month': 7, 'epiweek': 31, 'date': '2015-07-27', 'metric_value': 0.0, 'in_reporting_delay_period': False}]

# %%
# Let's filter for the year 2022.
# None values will be ignored by the APIwrapper

filters={"stratum" : None, # Smallest subgroup a metric can be broken down into e.g. ethnicity, testing pillar
         "age": None, # Smallest subgroup a metric can be broken down into e.g. 15_44 for the age group of 15-44 years
         "sex": None, #  Patient gender e.g. 'm' for Male, 'f' for Female or 'all' for all genders
         "year": 2015, #  Epi year of the metrics value (important for annual metrics) e.g. 2020
         "month": None, # Epi month of the metric value (important for monthly metrics) e.g. 12
         "epiweek" :None, # Epi week of the metric value (important for weekly metrics) e.g. 30
         "date" : None, # The date which this metric value was recorded in the format YYYY-MM-DD e.g. 2020-07-20
         "in_reporting_delay_period": None # Boolean indicating whether the data point is considered to be subject to retrospective updates
        }

# %%
data_2015=api.get_page(filters, page_size=3)
print(api.count)
print(data_2015)
# Out:
# 0
# []

# %%
structure={"theme": "infectious_disease", 
           "sub_theme": "respiratory",
           "topic": "Influenza",
           "geography_type": "Nation", 
           "geography": "England"}

# %%
structure["metric"]="influenza_healthcare_hospitalAdmissionRateByWeek"
api=APIwrapper(**structure)
cases=[]
page=1
while True:
    data=api.get_page(page_size=26)
    print(f"Pages retrieved: {page}")
    if data==[]:
        break
    cases.extend(data)
    page+=1
print(f"Data points expected: {api.count}")
print(f"Data points retrieved: {len(cases)}")
# Out:
# Pages retrieved: 1
# Pages retrieved: 2
# Pages retrieved: 3
# Pages retrieved: 4
# Pages retrieved: 5
# Pages retrieved: 6
# Pages retrieved: 7
# Pages retrieved: 8
# Pages retrieved: 9
# Pages retrieved: 10
# Pages retrieved: 11
# Pages retrieved: 12
# Pages retrieved: 13
# Pages retrieved: 14
# Pages retrieved: 15
# Pages retrieved: 16
# Pages retrieved: 17
# Pages retrieved: 18
# Pages retrieved: 19
# Pages retrieved: 20
# Pages retrieved: 21
# Pages retrieved: 22
# Pages retrieved: 23
# Pages retrieved: 24
# Pages retrieved: 25
# Pages retrieved: 26
# Pages retrieved: 27
# Pages retrieved: 28
# Pages retrieved: 29
# Pages retrieved: 30
# Pages retrieved: 31
# Pages retrieved: 32
# Pages retrieved: 33
# Pages retrieved: 34
# Pages retrieved: 35
# Pages retrieved: 36
# Pages retrieved: 37
# Pages retrieved: 38
# Pages retrieved: 39
# Pages retrieved: 40
# Pages retrieved: 41
# Pages retrieved: 42
# Pages retrieved: 43
# Pages retrieved: 44
# Pages retrieved: 45
# Pages retrieved: 46
# Pages retrieved: 47
# Pages retrieved: 48
# Pages retrieved: 49
# Pages retrieved: 50
# Pages retrieved: 51
# Pages retrieved: 52
# Pages retrieved: 53
# Pages retrieved: 54
# Pages retrieved: 55
# Pages retrieved: 56
# Pages retrieved: 57
# Pages retrieved: 58
# Pages retrieved: 59
# Pages retrieved: 60
# Pages retrieved: 61
# Pages retrieved: 62
# Pages retrieved: 63
# Pages retrieved: 64
# Pages retrieved: 65
# Pages retrieved: 66
# Pages retrieved: 67
# Pages retrieved: 68
# Pages retrieved: 69
# Pages retrieved: 70
# Pages retrieved: 71
# Pages retrieved: 72
# Pages retrieved: 73
# Pages retrieved: 74
# Pages retrieved: 75
# Pages retrieved: 76
# Pages retrieved: 77
# Pages retrieved: 78
# Pages retrieved: 79
# Pages retrieved: 80
# Pages retrieved: 81
# Pages retrieved: 82
# Pages retrieved: 83
# Pages retrieved: 84
# Pages retrieved: 85
# Pages retrieved: 86
# Pages retrieved: 87
# Pages retrieved: 88
# Data points expected: 2238
# Data points retrieved: 2238

# %% [markdown]
# After checking that the metrics work, we can do the same for ICU and Testing:

# %%
structure["metric"]="influenza_healthcare_ICUHDUadmissionRateByWeek"
# the structure has changed, so we need to create a new object
api=APIwrapper(**structure)
ICU=[]
while True:
    data=api.get_page(page_size=26)
    if data==[]:
        break
    ICU.extend(data)

# %%
structure["metric"]="influenza_testing_positivityByWeek"
api=APIwrapper(**structure)
testing=[]
while True:
    data=api.get_page(page_size=26)
    if data==[]:
        break
    testing.extend(data)

# %%
import json

# %%
with open("ICU.json", "wt") as OUTF:
    json.dump(ICU, OUTF)

# %%
with open("testing.json", "wt") as OUTF:
    json.dump(testing, OUTF)

# %%
with open("cases.json", "wt") as OUTF:
    json.dump(cases, OUTF)

# %% [markdown]
# ## VIsualise

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import json

# %%
# an iPython  "magic" that enables the embedding of matplotlib output
# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100

# %%
with open("ICU.json", "rt") as INFILE:
    ICU=json.load(INFILE)
with open("testing.json", "rt") as INFILE:
    testing=json.load(INFILE)
with open("cases.json", "rt") as INFILE:
    cases=json.load(INFILE)

# %%
cases[:5]
# Out:
# [{'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'Influenza',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#   'metric_group': 'healthcare',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2015,
#   'month': 6,
#   'epiweek': 27,
#   'date': '2015-06-29',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'Influenza',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#   'metric_group': 'healthcare',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2015,
#   'month': 7,
#   'epiweek': 28,
#   'date': '2015-07-06',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'Influenza',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#   'metric_group': 'healthcare',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2015,
#   'month': 7,
#   'epiweek': 29,
#   'date': '2015-07-13',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'Influenza',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#   'metric_group': 'healthcare',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2015,
#   'month': 7,
#   'epiweek': 30,
#   'date': '2015-07-20',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'Influenza',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'influenza_healthcare_hospitalAdmissionRateByWeek',
#   'metric_group': 'healthcare',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2015,
#   'month': 7,
#   'epiweek': 31,
#   'date': '2015-07-27',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False}]

# %%
data={}
for dataset in [ICU, cases, testing]:
    for entry in dataset:
        date=entry['date']
        metric=entry['metric']
        value=entry['metric_value']
        if date not in data:
            data[date]={}
        data[date][metric]=value

# %%
data
# Out:
# {'2015-06-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-07-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-07-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-07-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-07-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-08-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-08-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-08-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-08-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-08-31': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-09-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-09-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-09-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2015-09-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.08},
#  '2015-10-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.1},
#  '2015-10-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.04},
#  '2015-10-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01},
#  '2015-10-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07},
#  '2015-11-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01},
#  '2015-11-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.04},
#  '2015-11-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07},
#  '2015-11-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.06},
#  '2015-11-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11},
#  '2015-12-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.19},
#  '2015-12-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.19},
#  '2015-12-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.09,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.39},
#  '2016-01-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.12,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.66},
#  '2016-01-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.12,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.56},
#  '2016-01-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.18,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.91},
#  '2016-01-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.24,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.1},
#  '2016-02-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.29,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.86},
#  '2016-02-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.29,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.44},
#  '2016-02-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.32,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.89},
#  '2016-02-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.31,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.94},
#  '2016-02-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.33,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.37},
#  '2016-03-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.32,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.78},
#  '2016-03-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.34,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.82},
#  '2016-03-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.3,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.39},
#  '2016-03-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.31,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.58},
#  '2016-04-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.22,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.65},
#  '2016-04-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.13,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.82},
#  '2016-04-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.56},
#  '2016-04-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.44},
#  '2016-05-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.32},
#  '2016-05-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.38},
#  '2016-05-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.19},
#  '2016-05-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-05-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-06-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-06-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-06-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-06-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-07-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-07-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-07-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-07-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-08-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-08-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-08-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-08-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-08-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-09-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-09-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-09-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-09-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2016-10-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01},
#  '2016-10-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01},
#  '2016-10-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.05},
#  '2016-10-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.04},
#  '2016-10-31': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.03},
#  '2016-11-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.04},
#  '2016-11-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.03},
#  '2016-11-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.32},
#  '2016-11-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.56},
#  '2016-12-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.42},
#  '2016-12-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.08,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.81},
#  '2016-12-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.1,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.56},
#  '2016-12-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.18,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.98},
#  '2017-01-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.2,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.3},
#  '2017-01-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.19,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.38},
#  '2017-01-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.15,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.13},
#  '2017-01-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.16,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.37},
#  '2017-01-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.16,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.58},
#  '2017-02-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.14,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.69},
#  '2017-02-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.14,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.77},
#  '2017-02-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.1,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.51},
#  '2017-02-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.62},
#  '2017-03-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.52},
#  '2017-03-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.19},
#  '2017-03-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.1},
#  '2017-03-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.19},
#  '2017-04-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.08},
#  '2017-04-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11},
#  '2017-04-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11},
#  '2017-04-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.08},
#  '2017-05-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.14},
#  '2017-05-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.15},
#  '2017-05-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07},
#  '2017-05-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2017-05-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2017-06-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2017-06-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2017-06-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2017-06-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0},
#  '2017-07-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2017-07-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.8},
#  '2017-07-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2017-07-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2017-07-31': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.25},
#  '2017-08-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.97},
#  '2017-08-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 2.25},
#  '2017-08-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2017-08-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.74},
#  '2017-09-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 2.75},
#  '2017-09-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 3.93},
#  '2017-09-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.45},
#  '2017-09-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.65},
#  '2017-10-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.14,
#   'influenza_testing_positivityByWeek': 1.91},
#  '2017-10-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.08,
#   'influenza_testing_positivityByWeek': 2.56},
#  '2017-10-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.06,
#   'influenza_testing_positivityByWeek': 2.3},
#  '2017-10-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11,
#   'influenza_testing_positivityByWeek': 1.32},
#  '2017-10-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.05,
#   'influenza_testing_positivityByWeek': 1.02},
#  '2017-11-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07,
#   'influenza_testing_positivityByWeek': 0.66},
#  '2017-11-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.25,
#   'influenza_testing_positivityByWeek': 2.89},
#  '2017-11-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.35,
#   'influenza_testing_positivityByWeek': 3.95},
#  '2017-11-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.53,
#   'influenza_testing_positivityByWeek': 4.55},
#  '2017-12-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.78,
#   'influenza_testing_positivityByWeek': 9.12},
#  '2017-12-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.29,
#   'influenza_testing_positivityByWeek': 10.18},
#  '2017-12-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.16,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.85,
#   'influenza_testing_positivityByWeek': 19.88},
#  '2017-12-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.32,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.06,
#   'influenza_testing_positivityByWeek': 10.61},
#  '2018-01-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.4,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.33,
#   'influenza_testing_positivityByWeek': 10.59},
#  '2018-01-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.55,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 7.9,
#   'influenza_testing_positivityByWeek': 15.61},
#  '2018-01-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.52,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 7.02,
#   'influenza_testing_positivityByWeek': 29.59},
#  '2018-01-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.43,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.76,
#   'influenza_testing_positivityByWeek': 25.7},
#  '2018-01-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.41,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.64,
#   'influenza_testing_positivityByWeek': 28.91},
#  '2018-02-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.4,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.49,
#   'influenza_testing_positivityByWeek': 24.59},
#  '2018-02-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.37,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.25,
#   'influenza_testing_positivityByWeek': 25.94},
#  '2018-02-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.35,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.22,
#   'influenza_testing_positivityByWeek': 25.58},
#  '2018-02-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.32,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.2,
#   'influenza_testing_positivityByWeek': 22.25},
#  '2018-03-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.29,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.77,
#   'influenza_testing_positivityByWeek': 24.42},
#  '2018-03-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.28,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.28,
#   'influenza_testing_positivityByWeek': 10.63},
#  '2018-03-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.22,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.94,
#   'influenza_testing_positivityByWeek': 22.38},
#  '2018-03-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.18,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.55,
#   'influenza_testing_positivityByWeek': 14.06},
#  '2018-04-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.17,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.12,
#   'influenza_testing_positivityByWeek': 26.37},
#  '2018-04-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.14,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.05,
#   'influenza_testing_positivityByWeek': 7.25},
#  '2018-04-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.61,
#   'influenza_testing_positivityByWeek': 2.49},
#  '2018-04-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.3,
#   'influenza_testing_positivityByWeek': 1.18},
#  '2018-04-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.14,
#   'influenza_testing_positivityByWeek': 2.34},
#  '2018-05-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.09,
#   'influenza_testing_positivityByWeek': 2.11},
#  '2018-05-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.09,
#   'influenza_testing_positivityByWeek': 3.58},
#  '2018-05-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.29},
#  '2018-05-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-06-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-06-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.34},
#  '2018-06-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.69},
#  '2018-06-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.04},
#  '2018-07-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.36},
#  '2018-07-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.32},
#  '2018-07-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-07-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-07-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.54},
#  '2018-08-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-08-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-08-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.47},
#  '2018-08-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.33},
#  '2018-09-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 5.16},
#  '2018-09-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.47},
#  '2018-09-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-09-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-10-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.04,
#   'influenza_testing_positivityByWeek': 0.48},
#  '2018-10-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07,
#   'influenza_testing_positivityByWeek': 0.58},
#  '2018-10-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.02,
#   'influenza_testing_positivityByWeek': 0.48},
#  '2018-10-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2018-10-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07,
#   'influenza_testing_positivityByWeek': 1.8},
#  '2018-11-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.17,
#   'influenza_testing_positivityByWeek': 4.13},
#  '2018-11-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.18,
#   'influenza_testing_positivityByWeek': 4.19},
#  '2018-11-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.24,
#   'influenza_testing_positivityByWeek': 9.33},
#  '2018-11-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.35,
#   'influenza_testing_positivityByWeek': 1.39},
#  '2018-12-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.07,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.48,
#   'influenza_testing_positivityByWeek': 3.52},
#  '2018-12-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.1,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.72,
#   'influenza_testing_positivityByWeek': 10.36},
#  '2018-12-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.18,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.95,
#   'influenza_testing_positivityByWeek': 8.96},
#  '2018-12-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.3,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.13,
#   'influenza_testing_positivityByWeek': 12.77},
#  '2018-12-31': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.4,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.17,
#   'influenza_testing_positivityByWeek': 22.01},
#  '2019-01-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.51,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.26,
#   'influenza_testing_positivityByWeek': 24.17},
#  '2019-01-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.54,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.51,
#   'influenza_testing_positivityByWeek': 20.97},
#  '2019-01-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.54,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.33,
#   'influenza_testing_positivityByWeek': 21.09},
#  '2019-01-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.54,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.39,
#   'influenza_testing_positivityByWeek': 28.24},
#  '2019-02-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.52,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.07,
#   'influenza_testing_positivityByWeek': 28.11},
#  '2019-02-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.51,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.25,
#   'influenza_testing_positivityByWeek': 28.69},
#  '2019-02-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.37,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.68,
#   'influenza_testing_positivityByWeek': 21.7},
#  '2019-02-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.23,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.87,
#   'influenza_testing_positivityByWeek': 14.94},
#  '2019-03-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.18,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.36,
#   'influenza_testing_positivityByWeek': 7.84},
#  '2019-03-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.09,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.33,
#   'influenza_testing_positivityByWeek': 11.38},
#  '2019-03-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.08,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.01,
#   'influenza_testing_positivityByWeek': 4.88},
#  '2019-03-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.94,
#   'influenza_testing_positivityByWeek': 7.89},
#  '2019-04-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.76,
#   'influenza_testing_positivityByWeek': 4.63},
#  '2019-04-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.07,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.62,
#   'influenza_testing_positivityByWeek': 7.22},
#  '2019-04-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.56,
#   'influenza_testing_positivityByWeek': 7.16},
#  '2019-04-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.69,
#   'influenza_testing_positivityByWeek': 5.54},
#  '2019-04-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.24,
#   'influenza_testing_positivityByWeek': 8.85},
#  '2019-05-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.17,
#   'influenza_testing_positivityByWeek': 1.52},
#  '2019-05-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.23,
#   'influenza_testing_positivityByWeek': 1.72},
#  '2019-05-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 2.6},
#  '2019-05-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.81},
#  '2019-06-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 2.17},
#  '2019-06-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.73},
#  '2019-06-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.47},
#  '2019-06-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.9},
#  '2019-07-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.63},
#  '2019-07-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.95},
#  '2019-07-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.09},
#  '2019-07-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.74},
#  '2019-07-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.24},
#  '2019-08-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2019-08-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.32},
#  '2019-08-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 3.56},
#  '2019-08-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.86},
#  '2019-09-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2019-09-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.36},
#  '2019-09-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.25},
#  '2019-09-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 7.36},
#  '2019-09-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.03,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2019-10-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.26,
#   'influenza_testing_positivityByWeek': 4.76},
#  '2019-10-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.19,
#   'influenza_testing_positivityByWeek': 2.06},
#  '2019-10-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.55,
#   'influenza_testing_positivityByWeek': 1.29},
#  '2019-10-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.44,
#   'influenza_testing_positivityByWeek': 3.91},
#  '2019-11-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.78,
#   'influenza_testing_positivityByWeek': 1.48},
#  '2019-11-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.19,
#   'influenza_testing_positivityByWeek': 8.42},
#  '2019-11-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.08,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.48,
#   'influenza_testing_positivityByWeek': 15.18},
#  '2019-11-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.14,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.56,
#   'influenza_testing_positivityByWeek': 41.41},
#  '2019-12-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.22,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.76,
#   'influenza_testing_positivityByWeek': 13.13},
#  '2019-12-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.34,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.85,
#   'influenza_testing_positivityByWeek': 28.56},
#  '2019-12-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.43,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.42,
#   'influenza_testing_positivityByWeek': 22.58},
#  '2019-12-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.42,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.7,
#   'influenza_testing_positivityByWeek': 25.87},
#  '2019-12-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.37,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.14,
#   'influenza_testing_positivityByWeek': 22.02},
#  '2020-01-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.2,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.29,
#   'influenza_testing_positivityByWeek': 10.0},
#  '2020-01-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.12,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.25,
#   'influenza_testing_positivityByWeek': 6.78},
#  '2020-01-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.1,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.89,
#   'influenza_testing_positivityByWeek': 4.39},
#  '2020-01-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.07,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.18,
#   'influenza_testing_positivityByWeek': 6.6},
#  '2020-02-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.81,
#   'influenza_testing_positivityByWeek': 5.73},
#  '2020-02-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.07,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.84,
#   'influenza_testing_positivityByWeek': 6.71},
#  '2020-02-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.09,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.78,
#   'influenza_testing_positivityByWeek': 5.85},
#  '2020-02-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.06,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.01,
#   'influenza_testing_positivityByWeek': 5.45},
#  '2020-03-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.86,
#   'influenza_testing_positivityByWeek': 5.49},
#  '2020-03-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.57,
#   'influenza_testing_positivityByWeek': 3.91},
#  '2020-03-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.15,
#   'influenza_testing_positivityByWeek': 2.2},
#  '2020-03-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.13,
#   'influenza_testing_positivityByWeek': 1.76},
#  '2020-03-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.02,
#   'influenza_testing_positivityByWeek': 0.1},
#  '2020-04-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.08,
#   'influenza_testing_positivityByWeek': 0.41},
#  '2020-04-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-04-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.03},
#  '2020-04-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-05-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.03,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-05-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-05-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-05-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-06-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-06-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-06-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-06-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-06-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-07-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-07-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-07-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.12},
#  '2020-07-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-08-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-08-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-08-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-08-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-08-31': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-09-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-09-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.87},
#  '2020-09-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-09-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.19},
#  '2020-10-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-10-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.32,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-10-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.03,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-10-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-11-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-11-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-11-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.24},
#  '2020-11-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-11-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-12-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-12-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.16},
#  '2020-12-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2020-12-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-01-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-01-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-01-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.02,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-01-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-02-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-02-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-02-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-02-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.02},
#  '2021-03-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2021-03-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.02,
# ...
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.41,
#   'influenza_testing_positivityByWeek': 2.33},
#  '2023-02-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.89,
#   'influenza_testing_positivityByWeek': 0.88},
#  '2023-02-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.08,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.59,
#   'influenza_testing_positivityByWeek': 0.47},
#  '2023-02-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.1,
#   'influenza_testing_positivityByWeek': 0.55},
#  '2023-02-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.02,
#   'influenza_testing_positivityByWeek': 5.12},
#  '2023-03-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.92,
#   'influenza_testing_positivityByWeek': 0.66},
#  '2023-03-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.87,
#   'influenza_testing_positivityByWeek': 0.87},
#  '2023-03-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.17,
#   'influenza_testing_positivityByWeek': 0.71},
#  '2023-03-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.48,
#   'influenza_testing_positivityByWeek': 1.95},
#  '2023-04-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 5.57},
#  '2023-04-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.07,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.37,
#   'influenza_testing_positivityByWeek': 1.31},
#  '2023-04-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.37,
#   'influenza_testing_positivityByWeek': 0.15},
#  '2023-04-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.36,
#   'influenza_testing_positivityByWeek': 1.76},
#  '2023-05-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.22,
#   'influenza_testing_positivityByWeek': 0.41},
#  '2023-05-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.1},
#  '2023-05-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2023-05-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11,
#   'influenza_testing_positivityByWeek': 0.68},
#  '2023-05-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.4},
#  '2023-06-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.48,
#   'influenza_testing_positivityByWeek': 0.15},
#  '2023-06-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2023-06-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.69},
#  '2023-06-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.47},
#  '2023-07-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.11,
#   'influenza_testing_positivityByWeek': 1.21},
#  '2023-07-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.27,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2023-07-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.36},
#  '2023-07-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.01,
#   'influenza_testing_positivityByWeek': 0.85},
#  '2023-07-31': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.2},
#  '2023-08-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.53,
#   'influenza_testing_positivityByWeek': 1.15},
#  '2023-08-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.1,
#   'influenza_testing_positivityByWeek': 0.42},
#  '2023-08-21': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.81},
#  '2023-08-28': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2023-09-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.16,
#   'influenza_testing_positivityByWeek': 1.28},
#  '2023-09-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.1,
#   'influenza_testing_positivityByWeek': 0.35},
#  '2023-09-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.09,
#   'influenza_testing_positivityByWeek': 0.09},
#  '2023-09-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.07,
#   'influenza_testing_positivityByWeek': 0.0},
#  '2023-10-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.15,
#   'influenza_testing_positivityByWeek': 0.93},
#  '2023-10-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.07,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.57},
#  '2023-10-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.17,
#   'influenza_testing_positivityByWeek': 0.6},
#  '2023-10-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.08,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.21,
#   'influenza_testing_positivityByWeek': 1.54},
#  '2023-10-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.34,
#   'influenza_testing_positivityByWeek': 1.19},
#  '2023-11-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.44,
#   'influenza_testing_positivityByWeek': 1.18},
#  '2023-11-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.41,
#   'influenza_testing_positivityByWeek': 1.22},
#  '2023-11-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.34,
#   'influenza_testing_positivityByWeek': 2.53},
#  '2023-11-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.68,
#   'influenza_testing_positivityByWeek': 1.49},
#  '2023-12-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.91,
#   'influenza_testing_positivityByWeek': 4.01},
#  '2023-12-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.71,
#   'influenza_testing_positivityByWeek': 15.81},
#  '2023-12-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.16,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 5.42,
#   'influenza_testing_positivityByWeek': 11.44},
#  '2023-12-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.26,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 15.98,
#   'influenza_testing_positivityByWeek': 3.6},
#  '2024-01-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.13,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.89,
#   'influenza_testing_positivityByWeek': 19.05},
#  '2024-01-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.11,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.4,
#   'influenza_testing_positivityByWeek': 10.34},
#  '2024-01-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.12,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 26.66,
#   'influenza_testing_positivityByWeek': 10.55},
#  '2024-01-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.4,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 4.78,
#   'influenza_testing_positivityByWeek': 18.32},
#  '2024-01-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.09,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.94,
#   'influenza_testing_positivityByWeek': 13.68},
#  '2024-02-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.2,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.84,
#   'influenza_testing_positivityByWeek': 11.56},
#  '2024-02-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.08,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.5,
#   'influenza_testing_positivityByWeek': 8.63},
#  '2024-02-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.86,
#   'influenza_testing_positivityByWeek': 8.81},
#  '2024-02-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.09,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 2.91,
#   'influenza_testing_positivityByWeek': 5.02},
#  '2024-03-04': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 8.8,
#   'influenza_testing_positivityByWeek': 4.89},
#  '2024-03-11': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.35,
#   'influenza_testing_positivityByWeek': 6.44},
#  '2024-03-18': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.09,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.83,
#   'influenza_testing_positivityByWeek': 4.45},
#  '2024-03-25': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.24,
#   'influenza_testing_positivityByWeek': 3.61},
#  '2024-04-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.03,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 6.88,
#   'influenza_testing_positivityByWeek': 6.63},
#  '2024-04-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 3.12,
#   'influenza_testing_positivityByWeek': 2.21},
#  '2024-04-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.29,
#   'influenza_testing_positivityByWeek': 3.2},
#  '2024-04-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.29,
#   'influenza_testing_positivityByWeek': 2.59},
#  '2024-04-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.04,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.62,
#   'influenza_testing_positivityByWeek': 2.69},
#  '2024-05-06': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.25,
#   'influenza_testing_positivityByWeek': 1.23},
#  '2024-05-13': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.13},
#  '2024-05-20': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.22,
#   'influenza_testing_positivityByWeek': 0.78},
#  '2024-05-27': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.54,
#   'influenza_testing_positivityByWeek': 0.91},
#  '2024-06-03': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.5,
#   'influenza_testing_positivityByWeek': 0.52},
#  '2024-06-10': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.01,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.72},
#  '2024-06-17': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.53,
#   'influenza_testing_positivityByWeek': 0.18},
#  '2024-06-24': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.67,
#   'influenza_testing_positivityByWeek': 0.57},
#  '2024-07-01': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.16,
#   'influenza_testing_positivityByWeek': 0.39},
#  '2024-07-08': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.77},
#  '2024-07-15': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.33,
#   'influenza_testing_positivityByWeek': 0.81},
#  '2024-07-22': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.81,
#   'influenza_testing_positivityByWeek': 1.43},
#  '2024-07-29': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.05,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.55,
#   'influenza_testing_positivityByWeek': 2.68},
#  '2024-08-05': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.03},
#  '2024-08-12': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.51},
#  '2024-08-19': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.42},
#  '2024-08-26': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.12,
#   'influenza_testing_positivityByWeek': 0.49},
#  '2024-09-02': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 0.49},
#  '2024-09-09': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.53,
#   'influenza_testing_positivityByWeek': 2.53},
#  '2024-09-16': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0,
#   'influenza_testing_positivityByWeek': 1.55},
#  '2024-09-23': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.7,
#   'influenza_testing_positivityByWeek': 1.84},
#  '2024-09-30': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 1.76,
#   'influenza_testing_positivityByWeek': 1.27},
#  '2024-10-07': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.02,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.56,
#   'influenza_testing_positivityByWeek': 3.76},
#  '2024-10-14': {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#   'influenza_healthcare_hospitalAdmissionRateByWeek': 0.97,
#   'influenza_testing_positivityByWeek': 1.18}}

# %%
data['2015-06-29']
# Out:
# {'influenza_healthcare_ICUHDUadmissionRateByWeek': 0.0,
#  'influenza_healthcare_hospitalAdmissionRateByWeek': 0.0}

# %%
dates=list(data.keys())
dates.sort()
dates
# Out:
# ['2015-06-29',
#  '2015-07-06',
#  '2015-07-13',
#  '2015-07-20',
#  '2015-07-27',
#  '2015-08-03',
#  '2015-08-10',
#  '2015-08-17',
#  '2015-08-24',
#  '2015-08-31',
#  '2015-09-07',
#  '2015-09-14',
#  '2015-09-21',
#  '2015-09-28',
#  '2015-10-05',
#  '2015-10-12',
#  '2015-10-19',
#  '2015-10-26',
#  '2015-11-02',
#  '2015-11-09',
#  '2015-11-16',
#  '2015-11-23',
#  '2015-11-30',
#  '2015-12-07',
#  '2015-12-14',
#  '2015-12-21',
#  '2016-01-04',
#  '2016-01-11',
#  '2016-01-18',
#  '2016-01-25',
#  '2016-02-01',
#  '2016-02-08',
#  '2016-02-15',
#  '2016-02-22',
#  '2016-02-29',
#  '2016-03-07',
#  '2016-03-14',
#  '2016-03-21',
#  '2016-03-28',
#  '2016-04-04',
#  '2016-04-11',
#  '2016-04-18',
#  '2016-04-25',
#  '2016-05-02',
#  '2016-05-09',
#  '2016-05-16',
#  '2016-05-23',
#  '2016-05-30',
#  '2016-06-06',
#  '2016-06-13',
#  '2016-06-20',
#  '2016-06-27',
#  '2016-07-04',
#  '2016-07-11',
#  '2016-07-18',
#  '2016-07-25',
#  '2016-08-01',
#  '2016-08-08',
#  '2016-08-15',
#  '2016-08-22',
#  '2016-08-29',
#  '2016-09-05',
#  '2016-09-12',
#  '2016-09-19',
#  '2016-09-26',
#  '2016-10-03',
#  '2016-10-10',
#  '2016-10-17',
#  '2016-10-24',
#  '2016-10-31',
#  '2016-11-07',
#  '2016-11-14',
#  '2016-11-21',
#  '2016-11-28',
#  '2016-12-05',
#  '2016-12-12',
#  '2016-12-19',
#  '2016-12-26',
#  '2017-01-02',
#  '2017-01-09',
#  '2017-01-16',
#  '2017-01-23',
#  '2017-01-30',
#  '2017-02-06',
#  '2017-02-13',
#  '2017-02-20',
#  '2017-02-27',
#  '2017-03-06',
#  '2017-03-13',
#  '2017-03-20',
#  '2017-03-27',
#  '2017-04-03',
#  '2017-04-10',
#  '2017-04-17',
#  '2017-04-24',
#  '2017-05-01',
#  '2017-05-08',
#  '2017-05-15',
#  '2017-05-22',
#  '2017-05-29',
#  '2017-06-05',
#  '2017-06-12',
#  '2017-06-19',
#  '2017-06-26',
#  '2017-07-03',
#  '2017-07-10',
#  '2017-07-17',
#  '2017-07-24',
#  '2017-07-31',
#  '2017-08-07',
#  '2017-08-14',
#  '2017-08-21',
#  '2017-08-28',
#  '2017-09-04',
#  '2017-09-11',
#  '2017-09-18',
#  '2017-09-25',
#  '2017-10-02',
#  '2017-10-09',
#  '2017-10-16',
#  '2017-10-23',
#  '2017-10-30',
#  '2017-11-06',
#  '2017-11-13',
#  '2017-11-20',
#  '2017-11-27',
#  '2017-12-04',
#  '2017-12-11',
#  '2017-12-18',
#  '2017-12-25',
#  '2018-01-01',
#  '2018-01-08',
#  '2018-01-15',
#  '2018-01-22',
#  '2018-01-29',
#  '2018-02-05',
#  '2018-02-12',
#  '2018-02-19',
#  '2018-02-26',
#  '2018-03-05',
#  '2018-03-12',
#  '2018-03-19',
#  '2018-03-26',
#  '2018-04-02',
#  '2018-04-09',
#  '2018-04-16',
#  '2018-04-23',
#  '2018-04-30',
#  '2018-05-07',
#  '2018-05-14',
#  '2018-05-21',
#  '2018-05-28',
#  '2018-06-04',
#  '2018-06-11',
#  '2018-06-18',
#  '2018-06-25',
#  '2018-07-02',
#  '2018-07-09',
#  '2018-07-16',
#  '2018-07-23',
#  '2018-07-30',
#  '2018-08-06',
#  '2018-08-13',
#  '2018-08-20',
#  '2018-08-27',
#  '2018-09-03',
#  '2018-09-10',
#  '2018-09-17',
#  '2018-09-24',
#  '2018-10-01',
#  '2018-10-08',
#  '2018-10-15',
#  '2018-10-22',
#  '2018-10-29',
#  '2018-11-05',
#  '2018-11-12',
#  '2018-11-19',
#  '2018-11-26',
#  '2018-12-03',
#  '2018-12-10',
#  '2018-12-17',
#  '2018-12-24',
#  '2018-12-31',
#  '2019-01-07',
#  '2019-01-14',
#  '2019-01-21',
#  '2019-01-28',
#  '2019-02-04',
#  '2019-02-11',
#  '2019-02-18',
#  '2019-02-25',
#  '2019-03-04',
#  '2019-03-11',
#  '2019-03-18',
#  '2019-03-25',
#  '2019-04-01',
#  '2019-04-08',
#  '2019-04-15',
#  '2019-04-22',
#  '2019-04-29',
#  '2019-05-06',
#  '2019-05-13',
#  '2019-05-20',
#  '2019-05-27',
#  '2019-06-03',
#  '2019-06-10',
#  '2019-06-17',
#  '2019-06-24',
#  '2019-07-01',
#  '2019-07-08',
#  '2019-07-15',
#  '2019-07-22',
#  '2019-07-29',
#  '2019-08-05',
#  '2019-08-12',
#  '2019-08-19',
#  '2019-08-26',
#  '2019-09-02',
#  '2019-09-09',
#  '2019-09-16',
#  '2019-09-23',
#  '2019-09-30',
#  '2019-10-07',
#  '2019-10-14',
#  '2019-10-21',
#  '2019-10-28',
#  '2019-11-04',
#  '2019-11-11',
#  '2019-11-18',
#  '2019-11-25',
#  '2019-12-02',
#  '2019-12-09',
#  '2019-12-16',
#  '2019-12-23',
#  '2019-12-30',
#  '2020-01-06',
#  '2020-01-13',
#  '2020-01-20',
#  '2020-01-27',
#  '2020-02-03',
#  '2020-02-10',
#  '2020-02-17',
#  '2020-02-24',
#  '2020-03-02',
#  '2020-03-09',
#  '2020-03-16',
#  '2020-03-23',
#  '2020-03-30',
#  '2020-04-06',
#  '2020-04-13',
#  '2020-04-20',
#  '2020-04-27',
#  '2020-05-04',
#  '2020-05-11',
#  '2020-05-18',
#  '2020-05-25',
#  '2020-06-01',
#  '2020-06-08',
#  '2020-06-15',
#  '2020-06-22',
#  '2020-06-29',
#  '2020-07-06',
#  '2020-07-13',
#  '2020-07-20',
#  '2020-07-27',
#  '2020-08-03',
#  '2020-08-10',
#  '2020-08-17',
#  '2020-08-24',
#  '2020-08-31',
#  '2020-09-07',
#  '2020-09-14',
#  '2020-09-21',
#  '2020-09-28',
#  '2020-10-05',
#  '2020-10-12',
#  '2020-10-19',
#  '2020-10-26',
#  '2020-11-02',
#  '2020-11-09',
#  '2020-11-16',
#  '2020-11-23',
#  '2020-11-30',
#  '2020-12-07',
#  '2020-12-14',
#  '2020-12-21',
#  '2020-12-28',
#  '2021-01-04',
#  '2021-01-11',
#  '2021-01-18',
#  '2021-01-25',
#  '2021-02-01',
#  '2021-02-08',
#  '2021-02-15',
#  '2021-02-22',
#  '2021-03-01',
#  '2021-03-08',
#  '2021-03-15',
#  '2021-03-22',
#  '2021-03-29',
#  '2021-04-05',
#  '2021-04-12',
#  '2021-04-19',
#  '2021-04-26',
#  '2021-05-03',
#  '2021-05-10',
#  '2021-05-17',
#  '2021-05-24',
#  '2021-05-31',
#  '2021-06-07',
#  '2021-06-14',
#  '2021-06-21',
#  '2021-06-28',
#  '2021-07-05',
#  '2021-07-12',
#  '2021-07-19',
#  '2021-07-26',
#  '2021-08-02',
#  '2021-08-09',
#  '2021-08-16',
#  '2021-08-23',
#  '2021-08-30',
#  '2021-09-06',
#  '2021-09-13',
#  '2021-09-20',
#  '2021-09-27',
#  '2021-10-04',
#  '2021-10-11',
#  '2021-10-18',
#  '2021-10-25',
#  '2021-11-01',
#  '2021-11-08',
#  '2021-11-15',
#  '2021-11-22',
#  '2021-11-29',
#  '2021-12-06',
#  '2021-12-13',
#  '2021-12-20',
#  '2021-12-27',
#  '2022-01-03',
#  '2022-01-10',
#  '2022-01-17',
#  '2022-01-24',
#  '2022-01-31',
#  '2022-02-07',
#  '2022-02-14',
#  '2022-02-21',
#  '2022-02-28',
#  '2022-03-07',
#  '2022-03-14',
#  '2022-03-21',
#  '2022-03-28',
#  '2022-04-04',
#  '2022-04-11',
#  '2022-04-18',
#  '2022-04-25',
#  '2022-05-02',
#  '2022-05-09',
#  '2022-05-16',
#  '2022-05-23',
#  '2022-05-30',
#  '2022-06-06',
#  '2022-06-13',
#  '2022-06-20',
#  '2022-06-27',
#  '2022-07-04',
#  '2022-07-11',
#  '2022-07-18',
#  '2022-07-25',
#  '2022-08-01',
#  '2022-08-08',
#  '2022-08-15',
#  '2022-08-22',
#  '2022-08-29',
#  '2022-09-05',
#  '2022-09-12',
#  '2022-09-19',
#  '2022-09-26',
#  '2022-10-03',
#  '2022-10-10',
#  '2022-10-17',
#  '2022-10-24',
#  '2022-10-31',
#  '2022-11-07',
#  '2022-11-14',
#  '2022-11-21',
#  '2022-11-28',
#  '2022-12-05',
#  '2022-12-12',
#  '2022-12-19',
#  '2022-12-26',
#  '2023-01-02',
#  '2023-01-09',
#  '2023-01-16',
#  '2023-01-23',
#  '2023-01-30',
#  '2023-02-06',
#  '2023-02-13',
#  '2023-02-20',
#  '2023-02-27',
#  '2023-03-06',
#  '2023-03-13',
#  '2023-03-20',
#  '2023-03-27',
#  '2023-04-03',
#  '2023-04-10',
#  '2023-04-17',
#  '2023-04-24',
#  '2023-05-01',
#  '2023-05-08',
#  '2023-05-15',
#  '2023-05-22',
#  '2023-05-29',
#  '2023-06-05',
#  '2023-06-12',
#  '2023-06-19',
#  '2023-06-26',
#  '2023-07-03',
#  '2023-07-10',
#  '2023-07-17',
#  '2023-07-24',
#  '2023-07-31',
#  '2023-08-07',
#  '2023-08-14',
#  '2023-08-21',
#  '2023-08-28',
#  '2023-09-04',
#  '2023-09-11',
#  '2023-09-18',
#  '2023-09-25',
#  '2023-10-02',
#  '2023-10-09',
#  '2023-10-16',
#  '2023-10-23',
#  '2023-10-30',
#  '2023-11-06',
#  '2023-11-13',
#  '2023-11-20',
#  '2023-11-27',
#  '2023-12-04',
#  '2023-12-11',
#  '2023-12-18',
#  '2023-12-25',
#  '2024-01-01',
#  '2024-01-08',
#  '2024-01-15',
#  '2024-01-22',
#  '2024-01-29',
#  '2024-02-05',
#  '2024-02-12',
#  '2024-02-19',
#  '2024-02-26',
#  '2024-03-04',
#  '2024-03-11',
#  '2024-03-18',
#  '2024-03-25',
#  '2024-04-01',
#  '2024-04-08',
#  '2024-04-15',
#  '2024-04-22',
#  '2024-04-29',
#  '2024-05-06',
#  '2024-05-13',
#  '2024-05-20',
#  '2024-05-27',
#  '2024-06-03',
#  '2024-06-10',
#  '2024-06-17',
#  '2024-06-24',
#  '2024-07-01',
#  '2024-07-08',
#  '2024-07-15',
#  '2024-07-22',
#  '2024-07-29',
#  '2024-08-05',
#  '2024-08-12',
#  '2024-08-19',
#  '2024-08-26',
#  '2024-09-02',
#  '2024-09-09',
#  '2024-09-16',
#  '2024-09-23',
#  '2024-09-30',
#  '2024-10-07',
#  '2024-10-14']

# %%
def parse_date(datestring):
    """ Convert a date string into a pandas datetime object """
    return pd.to_datetime(datestring, format="%Y-%m-%d")

# %%
startdate=parse_date(dates[0])
enddate=parse_date(dates[-1])
print (startdate, ' to ', enddate)
# Out:
# 2015-06-29 00:00:00  to  2024-10-14 00:00:00

# %%
index=pd.date_range(startdate, enddate, freq='W-MON')
timeseriesdf=pd.DataFrame(index=index, columns=['ICU', 'cases', 'testing'])
timeseriesdf
# Out:
#             ICU cases testing
# 2015-06-29  NaN   NaN     NaN
# 2015-07-06  NaN   NaN     NaN
# 2015-07-13  NaN   NaN     NaN
# 2015-07-20  NaN   NaN     NaN
# 2015-07-27  NaN   NaN     NaN
# ...         ...   ...     ...
# 2024-09-16  NaN   NaN     NaN
# 2024-09-23  NaN   NaN     NaN
# 2024-09-30  NaN   NaN     NaN
# 2024-10-07  NaN   NaN     NaN
# 2024-10-14  NaN   NaN     NaN
#
# [486 rows x 3 columns]

# %%
# translate the columns to our metrics
metrics ={'ICU': 'influenza_healthcare_ICUHDUadmissionRateByWeek',
          'cases': 'influenza_healthcare_hospitalAdmissionRateByWeek',
          'testing': 'influenza_testing_positivityByWeek'}

for date, entry in data.items(): # each entry is a dictionary with cases, admissions and deaths
    pd_date=parse_date(date) # convert to Pandas format
    for column in ['ICU', 'cases', 'testing']: 
        metric_name=metrics[column]
        # do not assume all values are there for every date - if a value is not available, insert a 0.0
        value= entry.get(metric_name, 0.0)
        # this is the way you access a specific location in the dataframe - use .loc
        # and put index,column in a single set of [ ]
        timeseriesdf.loc[date, column]=value
            
# fill in any remaining "holes" due to missing dates
timeseriesdf.fillna(0.0, inplace=True)
            
timeseriesdf
# Out:
# /tmp/ipykernel_456/434922448.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   timeseriesdf.fillna(0.0, inplace=True)
#              ICU  cases  testing
# 2015-06-29  0.00   0.00     0.00
# 2015-07-06  0.00   0.00     0.00
# 2015-07-13  0.00   0.00     0.00
# 2015-07-20  0.00   0.00     0.00
# 2015-07-27  0.00   0.00     0.00
# ...          ...    ...      ...
# 2024-09-16  0.00   0.00     1.55
# 2024-09-23  0.00   0.70     1.84
# 2024-09-30  0.00   1.76     1.27
# 2024-10-07  0.02   0.56     3.76
# 2024-10-14  0.00   0.97     1.18
#
# [486 rows x 3 columns]

# %%
ax=timeseriesdf.plot() # easy peasy...
ax.set_title('ICU, cases and testing');

# %%
ax=timeseriesdf.plot(logy=True) # ...lemon squeezy
ax.set_title('ICU, cases and admissions (log scale)');

# %%
# Create subplots for each series in the DataFrame
timeseriesdf.plot(subplots=True, figsize=(8, 8))  # Adjust the figsize for better readability
plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %%
timeseriesdf.plot(figsize=(10, 6))

# Add title and labels
plt.title("Weekly Influenza Rates: Hospital Admissions, ICU Admissions, and Testing Positivity")
plt.xlabel("Date")
plt.ylabel("Rate")
plt.legend(title="Metrics")
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # DIY Disease Tracking Dashboard

# %%
from IPython.display import clear_output
import ipywidgets as wdg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
import json

# %%
# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100

# %%
# Load JSON files and store the raw data in some variable. Edit as appropriate
jsondata={}

# %%
def wrangle_data(rawdata):
    """ Parameters: rawdata - data from json file or API call. Returns a dataframe.
    Edit to include the code that wrangles the data, creates the dataframe and fills it in. """
    df=pd.DataFrame(index=range(0,100), columns=['One', 'Two'])
    # we have no real data to wrangle, so we just generate two random walks.
    one=two=0.0
    for i in range(0,100):
        df.loc[i,'One']=one
        df.loc[i,'Two']=two
        one+=np.random.randn()
        two+=2*np.random.randn()
    return df

# putting the wrangling code into a function allows you to call it again after refreshing the data through 
# the API. You should call the function directly on the JSON data when the dashboard starts, by including 
# the call in this cell as below:
df=wrangle_data(jsondata) # df is the dataframe for plotting

# %%
# Place your API access code in this function. Do not call this function directly; it will be called by 
# the button callback. 
def access_api():
    """ Accesses the UKHSA API. Return data as a like-for-like replacement for the "canned" data loaded from the JSON file. """
    url = "https://api.ukhsa-dashboard.data.gov.uk/themes/infectious_disease/sub_themes/respiratory/topics/Influenza/geography_types/Nation/geographies/England/metrics/influenza_healthcare_hospitalAdmissionRateByWeek"
    return {}

# %%
# Printout from this function will be lost in Voila unless captured in an
# output widget - therefore, we give feedback to the user by changing the 
# appearance of the button
def api_button_callback(button):
    """ Button callback - it must take the button as its parameter (unused in this case).
    Accesses API, wrangles data, updates global variable df used for plotting. """
    # Get fresh data from the API. If you have time, include some error handling
    # around this call.
    apidata=access_api()
    # wrangle the data and overwrite the dataframe for plotting
    global df
    df=wrangle_data(apidata)
    # the graph won't refresh until the user interacts with the widget.
    # this function simulates the interaction, see Graph and Analysis below.
    # The function needs to be adapted to your graph; you can omit this call
    # in the first instance
    refresh_graph()
    # after all is done, you can switch the icon on the button to a "check" sign
    # and optionally disable the button - it won't be needed again. If you are 
    # implementing error handling, you can use icons "unlink" or "times" and 
    # change the button text to "Unavailable" when the api call fails.
    apibutton.icon="check"
    # apibutton.disabled=True

    
apibutton=wdg.Button(
    description='PANIC', # you may want to change this...
    disabled=False,
    button_style='danger', # 'success', 'info', 'warning', 'danger' or ''
    tooltip="Keep calm and carry on",
    # FontAwesome names without the `fa-` prefix - try "download"
    icon='exclamation-triangle'
)

# remember to register your button callback function with the button
apibutton.on_click(api_button_callback) # the name of your function inside these brackets

display(apibutton)

# run all cells before clicking on this button
# Out:
# Button(button_style='danger', description='PANIC', icon='exclamation-triangle', style=ButtonStyle(), tooltip='…

# %%
def plot_random_walk(walk):
    """ Our sample graph plotting function """
    df[walk].plot()
    plt.show() # important! update won't work properly without this

# a sample widget
whichwalk=wdg.Dropdown(
    options=['One', 'Two'],
    value='One',
    description='Walk no: ',
    disabled=False,
)

def refresh_graph():
    """ We change the value of the widget in order to force a redraw of the graph;
    this is useful when the data have been updated. This is a bit of a gimmick; it
    needs to be customised for one of your widgets. """
    current=whichwalk.value
    if current==whichwalk.options[0]:
        other=whichwalk.options[1]
    else:
        other=whichwalk.options[0]
    whichwalk.value=other # forces the redraw
    whichwalk.value=current # now we can change it back
    
# connect the plotting function and the widget    
graph=wdg.interactive_output(plot_random_walk, {'walk': whichwalk})

# actually displays the graph
display(whichwalk, graph)
# Out:
# Dropdown(description='Walk no: ', options=('One', 'Two'), value='One')
# Output()
